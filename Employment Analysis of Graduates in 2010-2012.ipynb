# %% [markdown]
# # Job Outcomes of Students Graduated in 2010-2012

# %% [markdown]
#  It is known that in recent years, the employment amount of graduates are highly dependent on their majors and their university of graduate. These factors are now the indicators of success mostly in today's world.
#
#  In order to analyze the metrics of these factors and their effects on employment results, we will using the original data on job outcomes which is released by American Community Survey.

# %% [markdown]
# Before analyzing our data, we need to import the required libraries that we are going to use in our analysis process.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
recent_grads = pd.read_csv("recent-grads.csv")
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
#recent_grads.tail()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
#recent_grads.describe()
recent_grads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 21 columns):
# Rank                    173 non-null int64
# Major_code              173 non-null int64
# Major                   173 non-null object
# Total                   172 non-null float64
# Men                     172 non-null float64
# Women                   172 non-null float64
# Major_category          173 non-null object
# ShareWomen              172 non-null float64
# Sample_size             173 non-null int64
# Employed                173 non-null int64
# Full_time               173 non-null int64
# Part_time               173 non-null int64
# Full_time_year_round    173 non-null int64
# Unemployed              173 non-null int64
# Unemployment_rate       173 non-null float64
# Median                  173 non-null int64
# P25th                   173 non-null int64
# P75th                   173 non-null int64
# College_jobs            173 non-null int64
# ...

# %%
raw_data_count = recent_grads.count()
print(raw_data_count)
# Out:
# Rank                    173
# Major_code              173
# Major                   173
# Total                   172
# Men                     172
# Women                   172
# Major_category          173
# ShareWomen              172
# Sample_size             173
# Employed                173
# Full_time               173
# Part_time               173
# Full_time_year_round    173
# Unemployed              173
# Unemployment_rate       173
# Median                  173
# P25th                   173
# P75th                   173
# College_jobs            173
# Non_college_jobs        173
# Low_wage_jobs           173
# dtype: int64

# %% [markdown]
# In order to analyze the data consistently, we are going to remove na values from out data

# %%
recent_grads = recent_grads.dropna()
cleaned_data_count = recent_grads.count()
print(cleaned_data_count)
# Out:
# Rank                    172
# Major_code              172
# Major                   172
# Total                   172
# Men                     172
# Women                   172
# Major_category          172
# ShareWomen              172
# Sample_size             172
# Employed                172
# Full_time               172
# Part_time               172
# Full_time_year_round    172
# Unemployed              172
# Unemployment_rate       172
# Median                  172
# P25th                   172
# P75th                   172
# College_jobs            172
# Non_college_jobs        172
# Low_wage_jobs           172
# dtype: int64

# %% [markdown]
# Now we can see that our data is consistent in terms of all columns

# %% [markdown]
# ## Plots for Analysis

# %% [markdown]
# As we cleaned our data, we can analyze the relationship between different columns and compare metrics such as majors, sexualities, and job types.

# %%
recent_grads.plot(x = 'Sample_size', y = 'Median', kind = 'scatter',title = 'Sample_size vs Median')

# %%
recent_grads.plot(x = 'Sample_size', y = 'Unemployment_rate', kind = 'scatter',title = 'Sample_size vs Unemployment_rate')

# %%
recent_grads.plot(x = 'Full_time', y = 'Median', kind = 'scatter',title = 'Full_time vs Median')

# %%
recent_grads.plot(x = 'ShareWomen', y = 'Unemployment_rate', kind = 'scatter',title = 'ShareWomen vs Unemployment_rate')

# %%
recent_grads.plot(x = 'Men', y = 'Median', kind = 'scatter',title = 'Men vs Median')

# %%
recent_grads.plot(x = 'Women', y = 'Median', kind = 'scatter',title = 'Women vs Median')

# %% [markdown]
# * We see that as the students prefer more popular majors, their salaries are getting closer to average of the salaries of all majors. As the popularity decreases, that amount starts to vary both positively and negatively.
# * As the number of women increases in a major, it can be seen that the salary starts the be closer but lower than the average.
# * The highest salaries are mostly given for low number of full-time employees. For high number of full-time employees we can state that the salaries are around 40.000.

# %% [markdown]
# ## Column Histograms

# %%
#recent_grads["Sample_size"].describe()
recent_grads["Sample_size"].hist(bins=50,range = (0,5000))

# %%
#recent_grads["Median"].describe()
recent_grads["Median"].hist(bins=30,range = (0,120000))

# %%
#recent_grads["Employed"].describe()
recent_grads["Employed"].hist(bins=50,range = (0,310000))

# %%
#recent_grads["Full_time"].describe()
recent_grads["Full_time"].hist(bins=50,range = (0,252000))

# %%
#recent_grads["ShareWomen"].describe()
recent_grads["ShareWomen"].hist(bins=20,range = (0,1))

# %%
#recent_grads["Unemployment_rate"].describe()
recent_grads["Unemployment_rate"].hist(bins=25,range = (0,0.22))

# %%
#recent_grads["Men"].describe()
recent_grads["Men"].hist(bins=30,range = (0,175000))

# %%
#recent_grads["Women"].describe()
recent_grads["Women"].hist(bins=25,range = (0,310000))

# %% [markdown]
# * Interestingly, around 60% of majors are predominated by female and 40 % of majors are dominated by male.
# * The most common median salary range can be stated as 30.000-50.000

# %% [markdown]
# ## An Approach with Scatter Matrix

# %% [markdown]
# Now for an easier analysis, we can plot our histograms and scatter plots with scatter matrixes. So first let's import it:

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[['Sample_size','Median']],figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f801903ae80>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size','Median','Unemployment_rate']],figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8018e5df98>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Men','Median','Women']],figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8018a5e240>,
# ...
#       dtype=object)

# %%
recent_grads[:10]['ShareWomen'].plot(kind='bar')

# %%
recent_grads[-10:]['ShareWomen'].plot(kind='bar')

# %%
recent_grads[:10]['Unemployment_rate'].plot(kind='bar')

# %%
recent_grads[-10:]['Unemployment_rate'].plot(kind='bar')

# %% [markdown]
# ## Men and Women Distribution in Different Major Categories

# %%
recent_grads["Major_category"].unique()
# Out:
# array(['Engineering', 'Business', 'Physical Sciences',
#        'Law & Public Policy', 'Computers & Mathematics',
#        'Industrial Arts & Consumer Services', 'Arts', 'Health',
#        'Social Science', 'Biology & Life Science', 'Education',
#        'Agriculture & Natural Resources', 'Humanities & Liberal Arts',
#        'Psychology & Social Work', 'Communications & Journalism',
#        'Interdisciplinary'], dtype=object)

# %%
Men_categories = []
Women_categories = []
for cat in recent_grads["Major_category"].unique():
    Men_categories.append(recent_grads.loc[recent_grads["Major_category"] == cat,'Men'].sum())
    Women_categories.append(recent_grads.loc[recent_grads["Major_category"] == cat,'Women'].sum())
new_frame = pd.DataFrame(recent_grads["Major_category"].unique(),columns =['Major_category'])

# %%
print(Men_categories)
print(Women_categories)
print(recent_grads["Major_category"].unique())
print(new_frame)
new_frame["Women"] = Women_categories
new_frame["Men"] = Men_categories
print(new_frame)
# Out:
# [408307.0, 667852.0, 95390.0, 91129.0, 208725.0, 103781.0, 134390.0, 75517.0, 256834.0, 184919.0, 103526.0, 40357.0, 272846.0, 98115.0, 131921.0, 2817.0]
# [129276.0, 634524.0, 90089.0, 87978.0, 90283.0, 126011.0, 222740.0, 387713.0, 273132.0, 268943.0, 455603.0, 35263.0, 440622.0, 382892.0, 260680.0, 9479.0]
# ['Engineering' 'Business' 'Physical Sciences' 'Law & Public Policy'
#  'Computers & Mathematics' 'Industrial Arts & Consumer Services' 'Arts'
#  'Health' 'Social Science' 'Biology & Life Science' 'Education'
#  'Agriculture & Natural Resources' 'Humanities & Liberal Arts'
#  'Psychology & Social Work' 'Communications & Journalism'
#  'Interdisciplinary']
#                          Major_category
# 0                           Engineering
# 1                              Business
# 2                     Physical Sciences
# 3                   Law & Public Policy
# 4               Computers & Mathematics
# 5   Industrial Arts & Consumer Services
# ...

# %%
new_frame.plot.bar(x='Major_category', y='Women')

# %%
new_frame.plot.bar(x='Major_category', y='Men')

# %% [markdown]
# We see that while women are mainly employed in Business, Arts, and Education, Men are mostly employed in Business and Engineering
